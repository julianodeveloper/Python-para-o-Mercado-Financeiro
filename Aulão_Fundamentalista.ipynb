# %%
# !pip install yfinance
# !pip install fundamentus
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 2.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 3.9 MB/s eta 0:00:00
# ...

# %%
import fundamentus
import numpy as np
import pandas as pd
import yfinance as yf
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %% [markdown]
# Análise Fundamentalista

# %%
df2 = fundamentus.get_resultado_raw()
df2
# Out:
# /usr/local/lib/python3.11/dist-packages/fundamentus/resultado.py:50: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(content.text, decimal=",", thousands='.')[0]
# Multiples  Cotação     P/L  P/VP    PSR  Div.Yield  P/Ativo  P/Cap.Giro  \
# papel
# AALR3        12.26  -11.33  1.63  1.551     0.0000    0.709      -12.87
# ABCB3         0.00    0.00  0.00  0.000     0.0000    0.000        0.00
# ABCB4        20.15    5.08  0.77  0.000     0.0816    0.000        0.00
# ABEV3        12.85   14.03  2.05  2.264     0.0520    1.246       42.48
# ABYA3         4.91 -214.80  1.76  2.055     0.0000    0.527        1.98
# ...            ...     ...   ...    ...        ...      ...         ...
# WLMM4        29.99    7.83  1.43  0.333     0.0463    0.951        2.53
# WMBY3        25.39  -19.30  2.87  0.836     0.0000    0.182        1.20
# ...

# %%
df = fundamentus.get_resultado()
df
# Out:
# /usr/local/lib/python3.11/dist-packages/fundamentus/resultado.py:50: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(content.text, decimal=",", thousands='.')[0]
# Multiples  cotacao      pl   pvp    psr      dy     pa    pcg  pebit   pacl  \
# papel
# AALR3        12.26  -11.33  1.63  1.551  0.0000  0.709 -12.87  23.74  -1.92
# ABCB3         0.00    0.00  0.00  0.000  0.0000  0.000   0.00   0.00   0.00
# ABCB4        20.15    5.08  0.77  0.000  0.0816  0.000   0.00   0.00   0.00
# ABEV3        12.85   14.03  2.05  2.264  0.0520  1.246  42.48  10.41 -23.08
# ABYA3         4.91 -214.80  1.76  2.055  0.0000  0.527   1.98  19.96  -2.75
# ...            ...     ...   ...    ...     ...    ...    ...    ...    ...
# WLMM4        29.99    7.83  1.43  0.333  0.0463  0.951   2.53   5.73   3.39
# ...

# %%
setor = fundamentus.list_papel_setor(2)
setor
# Out:
# /usr/local/lib/python3.11/dist-packages/fundamentus/setor.py:42: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(content.text, decimal=",", thousands='.')[0]
# ['AMBP3', 'SAPR4', 'SAPR11', 'SAPR3', 'CSMG3', 'SBSP3', 'ORVR3']

# %%
df2.query('index in @setor')
# Out:
# Multiples  Cotação    P/L   P/VP    PSR  Div.Yield  P/Ativo  P/Cap.Giro  \
# papel
# AMBP3       127.50 -74.85  12.06  3.464     0.0000    1.503        5.45
# CSMG3        22.51   6.11   1.09  1.088     0.1231    0.557        7.75
# ORVR3        41.43  21.49   4.38  3.942     0.0000    1.034        6.16
# SAPR11       28.33   5.54   0.79  1.250     0.0547    0.418        5.92
# SAPR3         5.88   5.75   0.82  1.298     0.0488    0.433        6.15
# SAPR4         5.62   5.50   0.78  1.240     0.0562    0.414        5.87
# SBSP3        94.16   6.90   1.70  1.809     0.0153    0.845       64.60
#
# Multiples  P/EBIT  P/Ativ Circ.Liq  EV/EBIT  EV/EBITDA  Mrg Ebit  Mrg. Líq.  \
# papel
# AMBP3       18.45            -3.88    22.68      15.63    0.1877    -0.0217
# CSMG3        3.82            -1.75     6.08       4.49    0.2850     0.1780
# ORVR3       15.36            -2.58    20.83      12.81    0.2567     0.2006
# ...

# %% [markdown]
# Indicadores de Lucratividade / Operacionais
# Margem EBIT
#
# Margem Líquida
#
# ROIC
#
# ROE
#
# Dividend Yeld
#
# 6)CAGR - Crescimento de receita dos últimos 5 anos

# %%
df.query('index in @setor').loc[:,['mrgebit','mrgliq','roic','roe', 'dy', 'c5y']]
# Out:
# Multiples  mrgebit  mrgliq    roic     roe      dy     c5y
# papel
# AMBP3       0.1877 -0.0217  0.1135 -0.1611  0.0000  0.5961
# CSMG3       0.2850  0.1780  0.1610  0.1780  0.1231  0.1030
# ORVR3       0.2567  0.2006  0.0865  0.2040  0.0000  0.3093
# SAPR11      0.3377  0.2257  0.1259  0.1427  0.0547  0.0943
# SAPR3       0.3377  0.2257  0.1259  0.1427  0.0488  0.0943
# SAPR4       0.3377  0.2257  0.1259  0.1427  0.0562  0.0943
# SBSP3       0.4519  0.2623  0.2227  0.2461  0.0153  0.1774
