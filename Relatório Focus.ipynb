# %% [markdown]
# Python BCB: https://wilsonfreitas.github.io/python-bcb
#
# API de Expectativas: https://olinda.bcb.gov.br/olinda/servico/Expectativas/versao/v1/documentacao

# %%
# !pip install python-bcb
# Out:
# Requirement already satisfied: python-bcb in /usr/local/lib/python3.11/dist-packages (0.3.0)
# Requirement already satisfied: httpx>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from python-bcb) (0.28.1)
# Requirement already satisfied: lxml>=4.9.2 in /usr/local/lib/python3.11/dist-packages (from python-bcb) (5.3.0)
# Requirement already satisfied: pandas>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from python-bcb) (2.2.2)
# Requirement already satisfied: requests>=2.31.0 in /usr/local/lib/python3.11/dist-packages (from python-bcb) (2.32.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx>=0.24.0->python-bcb) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx>=0.24.0->python-bcb) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx>=0.24.0->python-bcb) (1.0.7)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from httpx>=0.24.0->python-bcb) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx>=0.24.0->python-bcb) (0.14.0)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.0.0->python-bcb) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.0.0->python-bcb) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.0.0->python-bcb) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.0.0->python-bcb) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31.0->python-bcb) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31.0->python-bcb) (2.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->python-bcb) (1.17.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx>=0.24.0->python-bcb) (1.3.1)

# %%
from bcb import Expectativas

# %%
em = Expectativas()

# %%
em.describe()
# Out:
# EntitySets:
#   ExpectativasMercadoTop5Anuais
#   ExpectativaMercadoMensais
#   ExpectativasMercadoInflacao24Meses
#   ExpectativasMercadoInflacao12Meses
#   ExpectativasMercadoSelic
#   ExpectativasMercadoTop5Selic
#   ExpectativasMercadoTop5Mensais
#   ExpectativasMercadoTrimestrais
#   ExpectativasMercadoAnuais

# %%
ep = em.get_endpoint("ExpectativasMercadoAnuais")

# %%
def get_previsoes(indicador, ano):
    return  (ep.query()
        .filter(ep.Indicador == f"{indicador}")
        .filter(ep.Data >= f'{ano}-01-01')
        .filter(ep.DataReferencia == ano)
        .select(ep.Data, ep.Mediana)
        .collect())

# %%
get_previsoes('IPCA', 2025)
# Out:
#          Data  Mediana
# 0  2025-01-02   4.9944
# 1  2025-01-02   4.9978
# 2  2025-01-03   4.9932
# 3  2025-01-03   4.9932
# 4  2025-01-06   4.9977
# 5  2025-01-06   4.8745
# 6  2025-01-07   4.9944
# 7  2025-01-07   4.8489
# 8  2025-01-08   4.9956
# 9  2025-01-08   4.8486
# 10 2025-01-09   4.9956
# 11 2025-01-09   4.8898
# 12 2025-01-10   5.0001
# 13 2025-01-10   5.1400
# 14 2025-01-13   5.0243
# 15 2025-01-13   5.1105
# 16 2025-01-14   5.0551
# 17 2025-01-14   5.2037
# 18 2025-01-15   5.0551
# 19 2025-01-15   5.2037
# 20 2025-01-16   5.0632
# 21 2025-01-16   5.1900
# 22 2025-01-17   5.0764
# 23 2025-01-17   5.1105
# 24 2025-01-20   5.0698
# 25 2025-01-20   5.0767
# 26 2025-01-21   5.0984
# 27 2025-01-21   5.1410
# 28 2025-01-22   5.1400
# 29 2025-01-22   5.2000
# 30 2025-01-23   5.1410
# 31 2025-01-23   5.2000
# 32 2025-01-24   5.5000
# 33 2025-01-24   5.6436
# 34 2025-01-27   5.5001
# 35 2025-01-27   5.6528
# 36 2025-01-28   5.5035
# 37 2025-01-28   5.6468
# 38 2025-01-29   5.5075
# 39 2025-01-29   5.6500
# 40 2025-01-30   5.5082
# 41 2025-01-30   5.6615
# 42 2025-01-31   5.5100
# 43 2025-01-31   5.5800

# %%
get_previsoes('Selic', 2025)
# Out:
#          Data  Mediana
# 0  2025-01-02   15.000
# 1  2025-01-02   15.000
# 2  2025-01-03   15.000
# 3  2025-01-03   15.000
# 4  2025-01-06   15.000
# 5  2025-01-06   15.000
# 6  2025-01-07   15.000
# 7  2025-01-07   15.000
# 8  2025-01-08   15.000
# 9  2025-01-08   15.000
# 10 2025-01-09   15.000
# 11 2025-01-09   15.000
# 12 2025-01-10   15.000
# 13 2025-01-10   15.000
# 14 2025-01-13   15.000
# 15 2025-01-13   15.000
# 16 2025-01-14   15.000
# 17 2025-01-14   15.000
# 18 2025-01-15   15.000
# 19 2025-01-15   15.000
# 20 2025-01-16   15.000
# 21 2025-01-16   15.000
# 22 2025-01-17   15.000
# 23 2025-01-17   15.000
# 24 2025-01-20   15.000
# 25 2025-01-20   15.000
# 26 2025-01-21   15.000
# 27 2025-01-21   15.000
# 28 2025-01-22   15.000
# 29 2025-01-22   15.000
# 30 2025-01-23   15.000
# 31 2025-01-23   15.000
# 32 2025-01-24   15.000
# 33 2025-01-24   15.125
# 34 2025-01-27   15.000
# 35 2025-01-27   15.125
# 36 2025-01-28   15.000
# 37 2025-01-28   15.250
# 38 2025-01-29   15.000
# 39 2025-01-29   15.250
# 40 2025-01-30   15.000
# 41 2025-01-30   15.250
# 42 2025-01-31   15.000
# 43 2025-01-31   15.125

# %%
get_previsoes('Câmbio', 2025)
# Out:
#          Data  Mediana
# 0  2025-01-02   5.9997
# 1  2025-01-02   6.0000
# 2  2025-01-03   5.9999
# 3  2025-01-03   6.0000
# 4  2025-01-06   5.9997
# 5  2025-01-06   6.0750
# 6  2025-01-07   6.0000
# 7  2025-01-07   6.0000
# 8  2025-01-08   6.0000
# 9  2025-01-08   6.0000
# 10 2025-01-09   6.0000
# 11 2025-01-09   6.0000
# 12 2025-01-10   6.0000
# 13 2025-01-10   6.0000
# 14 2025-01-13   6.0000
# 15 2025-01-13   6.0000
# 16 2025-01-14   6.0000
# 17 2025-01-14   6.0650
# 18 2025-01-15   6.0000
# 19 2025-01-15   6.0650
# 20 2025-01-16   6.0000
# 21 2025-01-16   6.0800
# 22 2025-01-17   6.0000
# 23 2025-01-17   6.0582
# 24 2025-01-20   6.0000
# 25 2025-01-20   6.0800
# 26 2025-01-21   6.0000
# 27 2025-01-21   6.0000
# 28 2025-01-22   6.0000
# 29 2025-01-22   6.0000
# 30 2025-01-23   6.0000
# 31 2025-01-23   6.0000
# 32 2025-01-24   6.0000
# 33 2025-01-24   6.0000
# 34 2025-01-27   6.0000
# 35 2025-01-27   6.0000
# 36 2025-01-28   6.0000
# 37 2025-01-28   6.0000
# 38 2025-01-29   6.0000
# 39 2025-01-29   6.0000
# 40 2025-01-30   6.0000
# 41 2025-01-30   6.0000
# 42 2025-01-31   6.0000
# 43 2025-01-31   6.0754
