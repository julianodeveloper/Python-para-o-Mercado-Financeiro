# %%
# !pip install yfinance --upgrade --no-cache-dir
import yfinance as yf

# %%
import yfinance as yf
import pandas as pd
import random

tickers_ibov = ["ABEV3.SA", "AZUL4.SA", "B3SA3.SA", "BBAS3.SA", "BBDC3.SA", "BBDC4.SA", "BBSE3.SA", "BPAC11.SA", "BRAP4.SA","BRFS3.SA", "BRKM5.SA","CCRO3.SA", "CMIG4.SA", "COGN3.SA", "CRFB3.SA", "CSAN3.SA", "CSNA3.SA", "CVCB3.SA", "CYRE3.SA", "ECOR3.SA", "EGIE3.SA", "ELET3.SA", "ELET6.SA", "EMBR3.SA", "EQTL3.SA", "FLRY3.SA", "GGBR4.SA", "GOAU4.SA", "GOLL4.SA", "HAPV3.SA", "HYPE3.SA", "IRBR3.SA", "ITSA4.SA", "ITUB4.SA", "JBSS3.SA", "KLBN11.SA", "LREN3.SA", "MGLU3.SA", "MRFG3.SA", "MRVE3.SA", "MULT3.SA", "NTCO3.SA", "PCAR3.SA", "PETR3.SA", "PETR4.SA", "QUAL3.SA", "RADL3.SA", "RAIL3.SA", "RENT3.SA", "SANB11.SA", "SBSP3.SA", "SUZB3.SA", "TAEE11.SA", "TOTS3.SA", "UGPA3.SA", "USIM5.SA", "VALE3.SA", "VIVT3.SA", "WEGE3.SA", "YDUQ3.SA"]

dados_yahoo = pd.DataFrame()
for ticker in tickers_ibov:
    try:
        data = yf.download(ticker, period='1y')["Close"]
        dados_yahoo[ticker] = data
    except Exception as e:
        print(f"Error downloading data for {ticker}: {e}")

ibov = pd.DataFrame()
try:
    ibov = yf.download('BOVA11.SA', period='1y')["Close"]
except Exception as e:
    print(f"Error downloading data for BOVA11: {e}")

# Check if 'ibov' DataFrame is empty
if ibov.empty:
    print("Error: 'ibov' DataFrame is empty. Check the ticker symbol and data source.")
else:
    ibov = ibov / ibov.iloc[0] # Only execute division if DataFrame is not empty
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ...

# %%
tickers_ibov = "ABEV3.SA", "AZUL4.SA", "B3SA3.SA", "BBAS3.SA", "BBDC3.SA", "BBDC4.SA", "BBSE3.SA", "BPAC11.SA", "BRAP4.SA","BRFS3.SA", "BRKM5.SA","CCRO3.SA", "CMIG4.SA", "COGN3.SA", "CRFB3.SA", "CSAN3.SA", "CSNA3.SA", "CVCB3.SA", "CYRE3.SA", "ECOR3.SA", "EGIE3.SA", "ELET3.SA", "ELET6.SA", "EMBR3.SA", "EQTL3.SA", "FLRY3.SA", "GGBR4.SA", "GOAU4.SA", "GOLL4.SA", "HAPV3.SA", "HYPE3.SA", "IRBR3.SA", "ITSA4.SA", "ITUB4.SA", "JBSS3.SA", "KLBN11.SA", "LREN3.SA", "MGLU3.SA", "MRFG3.SA", "MRVE3.SA", "MULT3.SA", "NTCO3.SA", "PCAR3.SA", "PETR3.SA", "PETR4.SA", "QUAL3.SA", "RADL3.SA", "RAIL3.SA", "RENT3.SA", "SANB11.SA", "SBSP3.SA", "SUZB3.SA", "TAEE11.SA", "TOTS3.SA", "UGPA3.SA", "USIM5.SA", "VALE3.SA", "VIVT3.SA", "WEGE3.SA", "YDUQ3.SA"

dados_yahoo = yf.download(tickers=tickers_ibov, period='1y')["Close"]

ibov = yf.download('BOVA11.SA', period='1y')["Close"]
ibov = ibov / ibov.iloc[0]
# Out:
# [*********************100%***********************]  60 of 60 completed
# [*********************100%***********************]  1 of 1 completed

# %%
dados_yahoo.dropna(how='all', inplace=True)
dados_yahoo.dropna(axis=1, inplace=True, thresh=246)

# %%
dados_yahoo
# Out:
# Ticker       ABEV3.SA  AZUL4.SA   B3SA3.SA   BBAS3.SA   BBDC3.SA   BBDC4.SA  \
# Date
# 2024-03-05  12.083967     12.36  11.862336  26.794291  11.290313  12.587979
# 2024-03-06  12.027102     12.31  11.920723  27.191036  11.226164  12.679727
# 2024-03-07  11.989191     12.09  11.988842  26.932692  11.162015  12.624680
# 2024-03-08  12.169266     12.29  12.125078  26.669729  11.198672  12.698077
# 2024-03-11  12.131355     12.09  12.241853  26.402157  11.281150  12.771477
# ...               ...       ...        ...        ...        ...        ...
# 2025-02-25  11.090000      4.10  10.800000  28.230000  10.780000  11.770000
# 2025-02-26  11.700000      3.78  10.640000  28.070000  10.650000  11.540000
# 2025-02-27  12.320000      3.88  10.700000  27.959999  10.580000  11.470000
# 2025-02-28  12.220000      3.87  10.400000  27.309999  10.360000  11.240000
# 2025-03-05  12.730000      3.84  10.530000  27.809999  10.500000  11.480000
#
# ...

# %%
retorno = dados_yahoo.pct_change()
retorno
# Out:
# Ticker      ABEV3.SA  AZUL4.SA  B3SA3.SA  BBAS3.SA  BBDC3.SA  BBDC4.SA  \
# Date
# 2024-03-05       NaN       NaN       NaN       NaN       NaN       NaN
# 2024-03-06 -0.004706 -0.004045  0.004922  0.014807 -0.005682  0.007288
# 2024-03-07 -0.003152 -0.017872  0.005714 -0.009501 -0.005714 -0.004341
# 2024-03-08  0.015020  0.016543  0.011364 -0.009764  0.003284  0.005814
# 2024-03-11 -0.003115 -0.016273  0.009631 -0.010033  0.007365  0.005780
# ...              ...       ...       ...       ...       ...       ...
# 2025-02-25  0.005440  0.084656 -0.003690  0.015102  0.008419  0.012038
# 2025-02-26  0.055004 -0.078049 -0.014815 -0.005668 -0.012059 -0.019541
# 2025-02-27  0.052991  0.026455  0.005639 -0.003919 -0.006573 -0.006066
# 2025-02-28 -0.008117 -0.002577 -0.028037 -0.023247 -0.020794 -0.020052
# 2025-03-05  0.041735 -0.007752  0.012500  0.018308  0.013514  0.021352
#
# Ticker      BBSE3.SA  BPAC11.SA  BRAP4.SA  BRFS3.SA  ...  SBSP3.SA  SUZB3.SA  \
# ...

# %%
retorno_acumulado = (1+ retorno). cumprod()
retorno_acumulado.iloc [0] = 1
retorno_acumulado
# Out:
# Ticker      ABEV3.SA  AZUL4.SA  B3SA3.SA  BBAS3.SA  BBDC3.SA  BBDC4.SA  \
# Date
# 2024-03-05  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 2024-03-06  0.995294  0.995955  1.004922  1.014807  0.994318  1.007288
# 2024-03-07  0.992157  0.978155  1.010664  1.005165  0.988636  1.002915
# 2024-03-08  1.007059  0.994337  1.022149  0.995351  0.991883  1.008746
# 2024-03-11  1.003922  0.978155  1.031993  0.985365  0.999188  1.014577
# ...              ...       ...       ...       ...       ...       ...
# 2025-02-25  0.917745  0.331715  0.910445  1.053583  0.954801  0.935019
# 2025-02-26  0.968225  0.305825  0.896957  1.047611  0.943287  0.916748
# 2025-02-27  1.019533  0.313916  0.902015  1.043506  0.937087  0.911187
# 2025-02-28  1.011257  0.313107  0.876724  1.019247  0.917601  0.892915
# 2025-03-05  1.053462  0.310680  0.887683  1.037908  0.930001  0.911981
#
# Ticker      BBSE3.SA  BPAC11.SA  BRAP4.SA  BRFS3.SA  ...  SBSP3.SA  SUZB3.SA  \
# ...

# %%
carteira = random.sample(list(dados_yahoo.columns) , k=5)
carteira = 10000 * retorno_acumulado.loc[: , carteira]
carteira['saldo'] = carteira.sum(axis=1)
carteira["retorno"] = carteira['saldo'].pct_change()
carteira
# Out:
# Ticker          BRFS3.SA      AZUL4.SA      BBDC4.SA     KLBN11.SA  \
# Date
# 2024-03-05  10000.000000  10000.000000  10000.000000  10000.000000
# 2024-03-06  10125.470322   9959.547542  10072.884838   9932.733612
# 2024-03-07  10276.034340   9781.553793  10029.154996  10031.389196
# 2024-03-08  10476.789439   9943.365941  10087.462715   9883.407307
# 2024-03-11  10420.325856   9781.553793  10145.771950   9914.797495
# ...                  ...           ...           ...           ...
# 2025-02-25  12161.361945   3317.152119   9350.190497  10826.823081
# 2025-02-26  12258.085147   3058.252489   9167.476107  10660.496624
# 2025-02-27  11864.742731   3139.158756   9111.867742  10686.484761
# 2025-02-28  11561.676369   3131.067956   8929.153352  10275.866445
# 2025-03-05  12103.327777   3106.796133   9119.811253  10457.786379
#
# Ticker          HAPV3.SA         saldo   retorno
# Date
# 2024-03-05  10000.000000  50000.000000       NaN
# 2024-03-06  10079.999924  50170.636238  0.003413
# ...

# %%
for i in range(500):
  carteira = random.sample(list(dados_yahoo.columns) , k=5)
  carteira = 10000 * retorno_acumulado.loc[: , carteira]
  carteira['saldo'] = carteira.sum(axis=1)
  carteira['saldo'].plot(figsize=(18,8))

(ibov*50000).plot(linewidth=4, color='black')
# Out:
# <Axes: xlabel='Date'>
