# %%
# !pip install -q quandl

# %%
import pandas as pd 
import quandl

# %%
quandl.get("BCB/433", authtoken="XLx7czqpKhozhm3mBtMK")
# Out:
#             Value
# Date
# 1980-01-31   6.62
# 1980-02-29   4.62
# 1980-03-31   6.04
# 1980-04-30   5.29
# 1980-05-31   5.70
# ...           ...
# 2021-05-31   0.83
# 2021-06-30   0.53
# 2021-07-31   0.96
# 2021-08-31   0.87
# 2021-09-30   1.16
#
# [501 rows x 1 columns]

# %%
ipca = quandl.get('BCB/433')

# %%
ipca
# Out:
#             Value
# Date
# 1980-01-31   6.62
# 1980-02-29   4.62
# 1980-03-31   6.04
# 1980-04-30   5.29
# 1980-05-31   5.70
# ...           ...
# 2021-05-31   0.83
# 2021-06-30   0.53
# 2021-07-31   0.96
# 2021-08-31   0.87
# 2021-09-30   1.16
#
# [501 rows x 1 columns]

# %%
acucar = quandl.get('CEPEA/SUGAR_C')

# %%
acucar
# Out:
#             Price US$  Daily %  Monthly %
# Date
# 2013-01-23      22.02      NaN        NaN
# 2013-01-24      21.91      NaN        NaN
# 2013-01-25      22.02      NaN        NaN
# 2013-01-28      22.07      NaN        NaN
# 2013-01-29      22.38      NaN        NaN
# ...               ...      ...        ...
# 2021-05-07      21.12     0.52       3.83
# 2021-05-10      21.50     1.80       5.70
# 2021-05-11      21.38    -0.56       5.11
# 2021-05-12      21.67     1.36       6.54
# 2021-05-13      21.35    -1.48       4.97
#
# [2054 rows x 3 columns]

# %%
btc = quandl.get('BCHAIN/MKPRU')

# %%
btc
# Out:
#                Value
# Date
# 2009-01-02      0.00
# 2009-01-03      0.00
# 2009-01-04      0.00
# 2009-01-05      0.00
# 2009-01-06      0.00
# ...              ...
# 2021-10-11  54625.74
# 2021-10-12  57452.01
# 2021-10-13  56242.94
# 2021-10-14  57406.69
# 2021-10-15  57397.74
#
# [4670 rows x 1 columns]

# %%
btc.plot()
