# %%
! pip install investpy
# Out:
# Requirement already satisfied: investpy in /usr/local/lib/python3.11/dist-packages (1.0.8)
# Requirement already satisfied: Unidecode>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from investpy) (1.3.8)
# Requirement already satisfied: setuptools>=41.2.0 in /usr/local/lib/python3.11/dist-packages (from investpy) (75.1.0)
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.11/dist-packages (from investpy) (1.26.4)
# Requirement already satisfied: pandas>=0.25.1 in /usr/local/lib/python3.11/dist-packages (from investpy) (2.2.2)
# Requirement already satisfied: lxml>=4.4.1 in /usr/local/lib/python3.11/dist-packages (from investpy) (5.3.0)
# Requirement already satisfied: requests>=2.22.0 in /usr/local/lib/python3.11/dist-packages (from investpy) (2.32.3)
# Requirement already satisfied: pytz>=2019.3 in /usr/local/lib/python3.11/dist-packages (from investpy) (2025.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.25.1->investpy) (2.8.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.25.1->investpy) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.22.0->investpy) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.22.0->investpy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.22.0->investpy) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.22.0->investpy) (2025.1.31)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=0.25.1->investpy) (1.17.0)

# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import investpy

# %%
commodities_list = ['Gold', 'Copper', 'Silver', 'Palladium', 'Platinum']

# Now you can use the variable
commodities_list
# Out:
# ['Gold', 'Copper', 'Silver', 'Palladium', 'Platinum']

# %%
investpy.commodities.get_commodities(group=None)
# Out:
#                                  title        country             name  \
# 0   Real Time Streaming Futures Quotes                            Gold
# 1   Real Time Streaming Futures Quotes  united states           Copper
# 2   Real Time Streaming Futures Quotes                          Silver
# 3   Real Time Streaming Futures Quotes  united states        Palladium
# 4   Real Time Streaming Futures Quotes  united states         Platinum
# ..                                 ...            ...              ...
# 61  Real Time Streaming Futures Quotes  united states  US Soybean Meal
# 62  Real Time Streaming Futures Quotes  united states      US Soybeans
# 63  Real Time Streaming Futures Quotes  united states         US Wheat
# 64  Real Time Streaming Futures Quotes  united states          US Corn
# 65  Real Time Streaming Futures Quotes  united states             Oats
#
#                   full_name currency   group
# 0              Gold Futures      USD  metals
# 1            Copper Futures      USD  metals
# 2            Silver Futures      USD  metals
# 3         Palladium Futures      USD  metals
# 4          Platinum Futures      USD  metals
# ..                      ...      ...     ...
# 61  US Soybean Meal Futures      USD  grains
# 62      US Soybeans Futures      USD  grains
# 63         US Wheat Futures      USD  grains
# 64          US Corn Futures      USD  grains
# 65             Oats Futures      USD  grains
#
# [66 rows x 6 columns]

# %%
investpy.commodities.get_commodities_list()
# Out:
# ['Gold',
#  'Copper',
#  'Silver',
#  'Palladium',
#  'Platinum',
#  'Aluminum',
#  'Zinc',
#  'Lead',
#  'Nickel',
#  'Tin',
#  'Copper',
#  'Xetra-Gold',
#  'MCX Aluminum Mini',
#  'MCX Aluminum',
#  'MCX Copper',
#  'MCX Copper Mini',
#  'MCX Gold 1 Kg',
#  'MCX Gold Guinea',
#  'MCX Gold Mini',
#  'MCX Gold Petal',
#  'MCX Gold Petal Del',
#  'MCX Lead',
#  'MCX Lead Mini',
#  'MCX Nickel',
#  'MCX Nickel Mini',
#  'MCX Silver',
#  'MCX Silver Micro',
#  'MCX Silver Mini',
#  'MCX Zinc',
#  'MCX Zinc Mini',
#  'US Coffee C',
#  'US Cotton #2',
#  'US Sugar #11',
#  'Orange Juice',
#  'US Cocoa',
#  'London Coffee',
#  'London Cocoa',
#  'London Sugar',
#  'Lumber',
#  'MCX Cardamom',
#  'MCX Cotton',
#  'MCX Crude Palm Oil',
#  'MCX Kapas',
#  'MCX Mentha Oil',
#  'MCX Castor Seed',
#  'Live Cattle',
#  'Lean Hogs',
#  'Feeder Cattle',
#  'Brent Oil',
#  'Crude Oil WTI',
#  'London Gas Oil',
#  'Natural Gas',
#  'Heating Oil',
#  'Carbon Emissions',
#  'Gasoline RBOB',
#  'MCX Brent Oil',
#  'MCX Crude Oil WTI',
#  'MCX Natural Gas',
#  'London Wheat',
#  'Rough Rice',
#  'US Soybean Oil',
#  'US Soybean Meal',
#  'US Soybeans',
#  'US Wheat',
#  'US Corn',
#  'Oats']
